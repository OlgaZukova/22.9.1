# %% [markdown]
# <a href="https://colab.research.google.com/github/OlgaZukova/22.9.1/blob/master/Week4_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

df=pd.read_csv ('/content/W4_L3_diamonds.csv')
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df.shape
# Out:
# (53940, 11)

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0           1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1           2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2           3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3           4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4           5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5           6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6           7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7           8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8           9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9          10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
#
#       y     z
# 0  3.98  2.43
# 1  3.84  2.31
# 2  4.07  2.31
# 3  4.23  2.63
# 4  4.35  2.75
# 5  3.96  2.48
# 6  3.98  2.47
# 7  4.11  2.53
# 8  3.78  2.49
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
df.tail(9)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53931       53932   0.71    Premium     F     SI1   59.8   62.0   2756  5.74
# 53932       53933   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71
# 53933       53934   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69
# 53934       53935   0.72    Premium     D     SI1   62.7   59.0   2757  5.69
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53931  5.73  3.43
# 53932  5.76  3.47
# 53933  5.72  3.49
# 53934  5.73  3.58
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
df['cut']
# Out:
# 0            Ideal
# 1          Premium
# 2             Good
# 3          Premium
# 4             Good
#            ...
# 53935        Ideal
# 53936         Good
# 53937    Very Good
# 53938      Premium
# 53939        Ideal
# Name: cut, Length: 53940, dtype: object

# %%
df['cut'].head(20)
# Out:
# 0         Ideal
# 1       Premium
# 2          Good
# 3       Premium
# 4          Good
# 5     Very Good
# 6     Very Good
# 7     Very Good
# 8          Fair
# 9     Very Good
# 10         Good
# 11        Ideal
# 12      Premium
# 13        Ideal
# 14      Premium
# 15      Premium
# 16        Ideal
# 17         Good
# 18         Good
# 19    Very Good
# Name: cut, dtype: object

# %%
df[['cut','color']]
# Out:
#              cut color
# 0          Ideal     E
# 1        Premium     E
# 2           Good     E
# 3        Premium     I
# 4           Good     J
# ...          ...   ...
# 53935      Ideal     D
# 53936       Good     D
# 53937  Very Good     D
# 53938    Premium     H
# 53939      Ideal     D
#
# [53940 rows x 2 columns]

# %%
df[['cut','color']].head(20)
# Out:
#           cut color
# 0       Ideal     E
# 1     Premium     E
# 2        Good     E
# 3     Premium     I
# 4        Good     J
# 5   Very Good     J
# 6   Very Good     I
# 7   Very Good     H
# 8        Fair     E
# 9   Very Good     H
# 10       Good     J
# 11      Ideal     J
# 12    Premium     F
# 13      Ideal     J
# 14    Premium     E
# 15    Premium     E
# 16      Ideal     I
# 17       Good     J
# 18       Good     J
# 19  Very Good     J

# %%
df[['cut','color','price']].head(20)
# Out:
#           cut color  price
# 0       Ideal     E    326
# 1     Premium     E    326
# 2        Good     E    327
# 3     Premium     I    334
# 4        Good     J    335
# 5   Very Good     J    336
# 6   Very Good     I    336
# 7   Very Good     H    337
# 8        Fair     E    337
# 9   Very Good     H    338
# 10       Good     J    339
# 11      Ideal     J    340
# 12    Premium     F    342
# 13      Ideal     J    344
# 14    Premium     E    345
# 15    Premium     E    345
# 16      Ideal     I    348
# 17       Good     J    351
# 18       Good     J    351
# 19  Very Good     J    351

# %%
df[['cut','color','x','y','z']].head(20)
# Out:
#           cut color     x     y     z
# 0       Ideal     E  3.95  3.98  2.43
# 1     Premium     E  3.89  3.84  2.31
# 2        Good     E  4.05  4.07  2.31
# 3     Premium     I  4.20  4.23  2.63
# 4        Good     J  4.34  4.35  2.75
# 5   Very Good     J  3.94  3.96  2.48
# 6   Very Good     I  3.95  3.98  2.47
# 7   Very Good     H  4.07  4.11  2.53
# 8        Fair     E  3.87  3.78  2.49
# 9   Very Good     H  4.00  4.05  2.39
# 10       Good     J  4.25  4.28  2.73
# 11      Ideal     J  3.93  3.90  2.46
# 12    Premium     F  3.88  3.84  2.33
# 13      Ideal     J  4.35  4.37  2.71
# 14    Premium     E  3.79  3.75  2.27
# 15    Premium     E  4.38  4.42  2.68
# 16      Ideal     I  4.31  4.34  2.68
# 17       Good     J  4.23  4.29  2.70
# 18       Good     J  4.23  4.26  2.71
# 19  Very Good     J  4.21  4.27  2.66

# %%
sns.FacetGrid(df)

# %%
sns.FacetGrid(df, col='cut', row='color')

# %%
g = sns.FacetGrid(df, col='cut', row='color')

# %%
g = sns.FacetGrid(df, col='cut', row='color')
g.map(sns.scatterplot, "carat", "price")

# %%
g = sns.FacetGrid(df, col='cut', row='color', hue='clarity')
g.map(sns.scatterplot, "carat", "price")

# %%
newdf=df.head(40)
g = sns.FacetGrid(newdf, col='cut', row='color', hue='clarity')
g.map(sns.scatterplot, "carat", "price")
g.add_legend()

# %%
newdf=df.head(40)
g = sns.FacetGrid(newdf, col='cut', row='color', hue='clarity')
g.map(sns.histplot, "carat")
g.add_legend()

# %%
g = sns.FacetGrid(df, col="color")
g = g.map(plt.hist, "price", edgecolor ='w', linewidth=2)

# %%
g = sns.FacetGrid(df, col="color")
g = g.map(plt.hist, "price", edgecolor ='w',linewidth=2, color='#ff0000')

# %%
g = sns.FacetGrid(df, col='cut', row='color', height=4, aspect=1)
g.map(plt.scatter, "carat", "price")

# %%
g = sns.FacetGrid(df, col='cut', row='color', height=4, aspect=1)
g.map(plt.scatter, "carat", "price", s=90, color = '#00ff00')

# %%
g = sns.FacetGrid(df, col='cut', hue='clarity', palette='coolwarm', col_wrap=3, legend_out=True)
g.map(plt.scatter, "carat", "price", s=70)
g.add_legend()

# %%
res = sns.scatterplot(x="carat", y="price", data=df)
plt.show()
