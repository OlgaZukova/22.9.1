# %% [markdown]
# <a href="https://colab.research.google.com/github/OlgaZukova/22.9.1/blob/master/Week4_Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dfiris=pd.read_csv('/content/W4_L5_dataset_iris.csv')

# %%
plt.scatter(dfiris['sepal_length'],dfiris['sepal_width'])
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.title('Scatter plot on Iris dataset')
# Out:
# Text(0.5, 1.0, 'Scatter plot on Iris dataset')

# %%
plt.scatter(dfiris['sepal_length'],dfiris['sepal_width'],edgecolor=['r','b','g'])
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.title('Scatter plot on Iris dataset')
# Out:
# Text(0.5, 1.0, 'Scatter plot on Iris dataset')

# %%
sns.set_style("whitegrid")
sns.FacetGrid(dfiris, hue="species") \
.map(plt.scatter, "sepal_length", "sepal_width") \
.add_legend()
plt.show()

# %%
sns.set_style("whitegrid");
sns.pairplot(dfiris, hue="species", height=3);
plt.show()

# %%
# Check the column names of the dataframe
print(dfiris.columns)

# Correct the column name in the boxplot call
sns.boxplot(x="species", y="petal_length", data=dfiris)
plt.show()
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.jointplot(data=dfiris,x=dfiris['sepal_length'],y=dfiris['sepal_width'],kind='kde')

# %%
sns.jointplot(data=dfiris,x=dfiris['sepal_length'],y=dfiris['sepal_width'],kind='kde')

# %%
sns.set_style('darkgrid')

# %%
sns.jointplot(x=dfiris['sepal_length'],y=dfiris['sepal_width'])

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=dfiris)

# %%
sns.jointplot(x=dfiris['sepal_length'],y=dfiris['sepal_width'],kind='kde')

# %%
g=sns.jointplot(x=dfiris['sepal_length'],y=dfiris['sepal_width'])

# %%
type(g)
# Out:
# seaborn.axisgrid.JointGrid

# %%
g=sns.jointplot(x=dfiris['sepal_length'],y=dfiris['sepal_width'])
g.plot_joint(sns.kdeplot,color='gray',levels=5)

# %%
dfiris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.jointplot(x=dfiris['sepal_length'],y=dfiris['sepal_width'],hue=dfiris['species'],kind='kde')

# %%
sns.jointplot(x=dfiris['sepal_length'],y=dfiris['sepal_width'],hue=dfiris['species'], kind='kde')

# %%
sns.jointplot(x=dfiris['sepal_length'],y=dfiris['sepal_width'],hue=dfiris['species'],kind='kde')
